# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
with open('meteorite-landings.csv') as f:
   print(f)
# Out:
# <_io.TextIOWrapper name='meteorite-landings.csv' mode='r' encoding='cp1251'>

# %%
met=pd.read_csv('meteorite-landings.csv', encoding='cp1251')

# %%
met.head(2)
# Out:
#      name  id nametype recclass   mass  fall    year    reclat   reclong  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880.0  50.77500   6.08333
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951.0  56.18333  10.23333
#
#               GeoLocation
# 0   (50.775000, 6.083330)
# 1  (56.183330, 10.233330)

# %%
# met.shape
# met.columns

# met.describe()
# met.info()

# %%
# отсортированная частота появления
    #met['mass'].value_counts(dropna=True)

# %%
#перевод в другой тип данных
    #met['mass']= met['mass'].astype('float32')

# %%
#уникальные значения
#met['year'].nunique()

# %%
#показать значения с индексами
# met.loc[[1003, 1002], 'year']
# met.iloc[[1003, 1002]]

# %%
#for i in range(5):
#    print(met.iloc[[i], 1])

# %%
#met.nlargest(3, 'mass')

# %%
#met[met['mass']==21.0][['year']]

# %%
#подсчет количества значений
#met['year'].value_counts()

# %%
met.groupby('fall')[['mass']].max()
# Out:
#              mass
# fall
# Fell   23000000.0
# Found  60000000.0
